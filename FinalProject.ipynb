# %% [markdown]
# <a href="https://colab.research.google.com/github/Engshakta/BMI-Calculator/blob/main/FinalProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install openjdk-8-jdk -qq > /dev/null

# %%
# !java -version
# Out:
# openjdk version "11.0.25" 2024-10-15
# OpenJDK Runtime Environment (build 11.0.25+9-post-Ubuntu-1ubuntu122.04)
# OpenJDK 64-Bit Server VM (build 11.0.25+9-post-Ubuntu-1ubuntu122.04, mixed mode, sharing)

# %%
# !wget https://downloads.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# Out:
# --2025-01-27 10:44:04--  https://downloads.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# Resolving downloads.apache.org (downloads.apache.org)... 135.181.214.104, 88.99.208.237, 2a01:4f8:10a:39da::2, ...
# Connecting to downloads.apache.org (downloads.apache.org)|135.181.214.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 730107476 (696M) [application/x-gzip]
# Saving to: ‘hadoop-3.3.6.tar.gz’
#
# hadoop-3.3.6.tar.gz 100%[===================>] 696.28M  28.4MB/s    in 25s
#
# 2025-01-27 10:44:30 (27.3 MB/s) - ‘hadoop-3.3.6.tar.gz’ saved [730107476/730107476]

# %%
# !tar -xzvf hadoop-3.3.6.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-client/build/source/hadoop-hdfs-project/hadoop-hdfs-client/target/api/org/apache/hadoop/hdfs/web/resources/BufferSizeParam.html
# hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-client/build/source/hadoop-hdfs-project/hadoop-hdfs-client/target/api/org/apache/hadoop/hdfs/web/resources/DeleteOpParam.Op.html
# hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-client/build/source/hadoop-hdfs-project/hadoop-hdfs-client/target/api/org/apache/hadoop/hdfs/web/resources/PutOpParam.html
# hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-client/build/source/hadoop-hdfs-project/hadoop-hdfs-client/target/api/org/apache/hadoop/hdfs/web/resources/RenameOptionSetParam.html
# ...

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["HADOOP_HOME"] = "/content/hadoop-3.3.6"
os.environ["PATH"] = os.environ["PATH"] + ":" + os.environ["HADOOP_HOME"] + "/bin"

# %%
# !hadoop version
# Out:
# Hadoop 3.3.6
# Source code repository https://github.com/apache/hadoop.git -r 1be78238728da9266a4f88195058f08fd012bf9c
# Compiled by ubuntu on 2023-06-18T08:22Z
# Compiled on platform linux-x86_64
# Compiled with protoc 3.7.1
# From source with checksum 5652179ad55f76cb287d9c633bb53bbd
# This command was run using /content/hadoop-3.3.6/share/hadoop/common/hadoop-common-3.3.6.jar

# %%
# !hdfs namenode -format
# Out:
# WARNING: /content/hadoop-3.3.6/logs does not exist. Creating.
# 2025-01-27 10:47:17,763 INFO namenode.NameNode: STARTUP_MSG:
# /************************************************************
# STARTUP_MSG: Starting NameNode
# STARTUP_MSG:   host = 7a8859a1cd94/172.28.0.12
# STARTUP_MSG:   args = [-format]
# STARTUP_MSG:   version = 3.3.6
# ...

# %%
# !$HADOOP_HOME/sbin/start-dfs.sh
# Out:
# Starting namenodes on [7a8859a1cd94]
# ERROR: Attempting to operate on hdfs namenode as root
# ERROR: but there is no HDFS_NAMENODE_USER defined. Aborting operation.
# Starting datanodes
# ERROR: Attempting to operate on hdfs datanode as root
# ERROR: but there is no HDFS_DATANODE_USER defined. Aborting operation.
# Starting secondary namenodes [7a8859a1cd94]
# ERROR: Attempting to operate on hdfs secondarynamenode as root
# ERROR: but there is no HDFS_SECONDARYNAMENODE_USER defined. Aborting operation.

# %%
# !jps
# Out:
# 3865 Jps

# %%
# Install Java 8
# !apt-get update
# !apt-get install openjdk-8-jdk -qq > /dev/null

# Set Java 8 as the default
# !update-alternatives --config java

# Verify Java version
# !java -version

# Set JAVA_HOME
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["PATH"] = os.environ["PATH"] + ":" + os.environ["JAVA_HOME"] + "/bin"

# Verify Hadoop installation
# !hadoop version
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# ...

# %%
# !hadoop version
# Out:
# Hadoop 3.3.6
# Source code repository https://github.com/apache/hadoop.git -r 1be78238728da9266a4f88195058f08fd012bf9c
# Compiled by ubuntu on 2023-06-18T08:22Z
# Compiled on platform linux-x86_64
# Compiled with protoc 3.7.1
# From source with checksum 5652179ad55f76cb287d9c633bb53bbd
# This command was run using /content/hadoop-3.3.6/share/hadoop/common/hadoop-common-3.3.6.jar

# %%
# !hdfs namenode -format
# Out:
# 2025-01-27 10:55:05,936 INFO namenode.NameNode: STARTUP_MSG:
# /************************************************************
# STARTUP_MSG: Starting NameNode
# STARTUP_MSG:   host = 7a8859a1cd94/172.28.0.12
# STARTUP_MSG:   args = [-format]
# STARTUP_MSG:   version = 3.3.6
# ...

# %%
# !$HADOOP_HOME/sbin/start-dfs.sh
# Out:
# Starting namenodes on [7a8859a1cd94]
# ERROR: Attempting to operate on hdfs namenode as root
# ERROR: but there is no HDFS_NAMENODE_USER defined. Aborting operation.
# Starting datanodes
# ERROR: Attempting to operate on hdfs datanode as root
# ERROR: but there is no HDFS_DATANODE_USER defined. Aborting operation.
# Starting secondary namenodes [7a8859a1cd94]
# ERROR: Attempting to operate on hdfs secondarynamenode as root
# ERROR: but there is no HDFS_SECONDARYNAMENODE_USER defined. Aborting operation.

# %%
# !jps
# Out:
# 7868 Jps

# %%
# !hdfs dfs -mkdir /input

# %%
# !hdfs dfs -put /content/archive_2.zip /input

# %%
# !hdfs dfs -ls /input
# Out:
# Found 1 items
# -rw-r--r--   1 root root       8907 2025-01-27 11:00 /input/archive_2.zip

# %%
# !wget https://downloads.apache.org/hive/hive-3.1.3/apache-hive-3.1.3-bin.tar.gz
# !tar -xzvf apache-hive-3.1.3-bin.tar.gz
# Out:
# --2025-01-27 11:01:23--  https://downloads.apache.org/hive/hive-3.1.3/apache-hive-3.1.3-bin.tar.gz
# Resolving downloads.apache.org (downloads.apache.org)... 135.181.214.104, 88.99.208.237, 2a01:4f8:10a:39da::2, ...
# Connecting to downloads.apache.org (downloads.apache.org)|135.181.214.104|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-01-27 11:01:23 ERROR 404: Not Found.
#
# tar (child): apache-hive-3.1.3-bin.tar.gz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now

# %%
os.environ["HIVE_HOME"] = "/content/apache-hive-3.1.3-bin"
os.environ["PATH"] = os.environ["PATH"] + ":" + os.environ["HIVE_HOME"] + "/bin"

# %%
# !schematool -initSchema -dbType derby
# Out:
# /bin/bash: line 1: schematool: command not found

# %%
# !hive
# Out:
# /bin/bash: line 1: hive: command not found

# %%
import os
os.environ["HDFS_NAMENODE_USER"] = "root"
os.environ["HDFS_DATANODE_USER"] = "root"
os.environ["HDFS_SECONDARYNAMENODE_USER"] = "root"
os.environ["YARN_RESOURCEMANAGER_USER"] = "root"
os.environ["YARN_NODEMANAGER_USER"] = "root"

# %%
# !$HADOOP_HOME/sbin/stop-dfs.sh  # Stop HDFS if it's already running
# !$HADOOP_HOME/sbin/start-dfs.sh  # Start HDFS
# Out:
# Stopping namenodes on [7a8859a1cd94]
# ERROR: JAVA_HOME is not set and could not be found.
# Stopping datanodes
# ERROR: JAVA_HOME is not set and could not be found.
# Stopping secondary namenodes [7a8859a1cd94]
# ERROR: JAVA_HOME is not set and could not be found.
# Starting namenodes on [7a8859a1cd94]
# ERROR: JAVA_HOME is not set and could not be found.
# Starting datanodes
# ERROR: JAVA_HOME is not set and could not be found.
# Starting secondary namenodes [7a8859a1cd94]
# ERROR: JAVA_HOME is not set and could not be found.

# %%
# !jps
# Out:
# 9867 Jps

# %%
# !java -version
# Out:
# openjdk version "1.8.0_432"
# OpenJDK Runtime Environment (build 1.8.0_432-8u432-ga~us1-0ubuntu2~22.04-ga)
# OpenJDK 64-Bit Server VM (build 25.432-bga, mixed mode)

# %%
# !update-alternatives --list java
# Out:
# /usr/lib/jvm/java-11-openjdk-amd64/bin/java
# /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"  # Use the correct path from Step 2
os.environ["PATH"] = os.environ["PATH"] + ":" + os.environ["JAVA_HOME"] + "/bin"

# %%
# !echo $JAVA_HOME
# Out:
# /usr/lib/jvm/java-8-openjdk-amd64

# %%
# !$HADOOP_HOME/sbin/start-dfs.sh
# Out:
# Starting namenodes on [7a8859a1cd94]
# ERROR: JAVA_HOME is not set and could not be found.
# Starting datanodes
# ERROR: JAVA_HOME is not set and could not be found.
# Starting secondary namenodes [7a8859a1cd94]
# ERROR: JAVA_HOME is not set and could not be found.

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["PATH"] = os.environ["PATH"] + ":" + os.environ["JAVA_HOME"] + "/bin"

# %%
# Set JAVA_HOME in hadoop-env.sh
# !echo 'export JAVA_HOME=/usr/lib/jvm/java-8-openjdk-amd64' >> $HADOOP_HOME/etc/hadoop/hadoop-env.sh

# Restart Hadoop services
# !$HADOOP_HOME/sbin/stop-dfs.sh
# !$HADOOP_HOME/sbin/start-dfs.sh

# Verify Hadoop services
# !jps
# Out:
# Stopping namenodes on [7a8859a1cd94]
# 7a8859a1cd94: ssh: connect to host 7a8859a1cd94 port 22: Connection refused
# Stopping datanodes
# localhost: ssh: connect to host localhost port 22: Cannot assign requested address
# Stopping secondary namenodes [7a8859a1cd94]
# 7a8859a1cd94: ssh: connect to host 7a8859a1cd94 port 22: Connection refused
# Starting namenodes on [7a8859a1cd94]
# 7a8859a1cd94: ssh: connect to host 7a8859a1cd94 port 22: Connection refused
# Starting datanodes
# localhost: ssh: connect to host localhost port 22: Cannot assign requested address
# Starting secondary namenodes [7a8859a1cd94]
# 7a8859a1cd94: ssh: connect to host 7a8859a1cd94 port 22: Connection refused
# 11482 Jps

# %%
# !wget https://archive.apache.org/dist/hive/hive-3.1.3/apache-hive-3.1.3-bin.tar.gz
# Out:
# --2025-01-27 11:11:04--  https://archive.apache.org/dist/hive/hive-3.1.3/apache-hive-3.1.3-bin.tar.gz
# Resolving archive.apache.org (archive.apache.org)... 65.108.204.189, 2a01:4f9:1a:a084::2
# Connecting to archive.apache.org (archive.apache.org)|65.108.204.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 326940667 (312M) [application/x-gzip]
# Saving to: ‘apache-hive-3.1.3-bin.tar.gz’
#
# apache-hive-3.1.3-b 100%[===================>] 311.79M  28.0MB/s    in 12s
#
# 2025-01-27 11:11:16 (26.6 MB/s) - ‘apache-hive-3.1.3-bin.tar.gz’ saved [326940667/326940667]

# %%
# !tar -xzvf apache-hive-3.1.3-bin.tar.gz
# Out:
# apache-hive-3.1.3-bin/LICENSE
# apache-hive-3.1.3-bin/RELEASE_NOTES.txt
# apache-hive-3.1.3-bin/NOTICE
# apache-hive-3.1.3-bin/binary-package-licenses/com.thoughtworks.paranamer-LICENSE
# apache-hive-3.1.3-bin/binary-package-licenses/org.codehaus.janino-LICENSE
# apache-hive-3.1.3-bin/binary-package-licenses/org.jamon.jamon-runtime-LICENSE
# apache-hive-3.1.3-bin/binary-package-licenses/org.mozilla.rhino-LICENSE
# apache-hive-3.1.3-bin/binary-package-licenses/org.jruby-LICENSE
# apache-hive-3.1.3-bin/binary-package-licenses/jline-LICENSE
# apache-hive-3.1.3-bin/binary-package-licenses/org.antlr-LICENSE
# apache-hive-3.1.3-bin/binary-package-licenses/org.abego.treelayout.core-LICENSE
# apache-hive-3.1.3-bin/binary-package-licenses/sqlline-LICENSE
# apache-hive-3.1.3-bin/binary-package-licenses/org.slf4j-LICENSE
# apache-hive-3.1.3-bin/binary-package-licenses/org.antlr.antlr4-LICENSE
# apache-hive-3.1.3-bin/binary-package-licenses/com.google.protobuf-LICENSE
# ...

# %%
import os
os.environ["HIVE_HOME"] = "/content/apache-hive-3.1.3-bin"
os.environ["PATH"] = os.environ["PATH"] + ":" + os.environ["HIVE_HOME"] + "/bin"

# %%
import os
os.environ["HIVE_HOME"] = "/content/apache-hive-3.1.3-bin"

# %%
os.environ["PATH"] = os.environ["PATH"] + ":" + os.environ["HIVE_HOME"] + "/bin"

# %%
# !hdfs dfs -ls /input

# %%
# !hadoop fs -getmerge /input/archive_2.zip /tmp/archive_2.zip
# !unzip /tmp/archive_2.zip -d /tmp
# !hdfs dfs -put /tmp/StudentsPerformance.csv /input/StudentsPerformance.csv
# Out:
# Archive:  /tmp/archive_2.zip
#   inflating: /tmp/StudentsPerformance.csv

# %%
# !schematool -initSchema -dbType derby
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/content/apache-hive-3.1.3-bin/lib/log4j-slf4j-impl-2.17.1.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hadoop-3.3.6/share/hadoop/common/lib/slf4j-reload4j-1.7.36.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Metastore connection URL:	 jdbc:derby:;databaseName=metastore_db;create=true
# Metastore Connection Driver :	 org.apache.derby.jdbc.EmbeddedDriver
# Metastore connection User:	 APP
# Starting metastore schema initialization to 3.1.0
# Initialization script hive-schema-3.1.0.derby.sql
#
#
# Error: FUNCTION 'NUCLEUS_ASCII' already exists. (state=X0Y68,code=30000)
# org.apache.hadoop.hive.metastore.HiveMetaException: Schema initialization FAILED! Metastore state would be inconsistent !!
# ...

# %%
# !hive
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/content/apache-hive-3.1.3-bin/lib/log4j-slf4j-impl-2.17.1.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hadoop-3.3.6/share/hadoop/common/lib/slf4j-reload4j-1.7.36.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Hive Session ID = 5b07cfc9-ef79-43d4-ba04-922b18a4b305
#
# Logging initialized using configuration in jar:file:/content/apache-hive-3.1.3-bin/lib/hive-common-3.1.3.jar!/hive-log4j2.properties Async: true
# Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# Hive Session ID = 5ecfa05f-6a64-480f-bc0f-bc8c8481c91d
# ...

# %%
# !hdfs dfs -ls /input
# Out:
# Found 1 items
# -rw-r--r--   1 root root       8907 2025-01-27 11:00 /input/archive_2.zip

# %%
# !hadoop fs -getmerge /input/archive_2.zip /tmp/archive_2.zip
# !unzip /tmp/archive_2.zip -d /tmp
# !hdfs dfs -put /tmp/StudentsPerformance.csv /input/StudentsPerformance.csv
# Out:
# Archive:  /tmp/archive_2.zip
# replace /tmp/StudentsPerformance.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /tmp/StudentsPerformance.csv

# %%
# !hadoop fs -getmerge /input/archive_2.zip /tmp/archive_2.zip
# !unzip /tmp/archive_2.zip -d /tmp
# !hdfs dfs -put /tmp/StudentsPerformance.csv /input/StudentsPerformance.csv
# Out:
# Archive:  /tmp/archive_2.zip
# replace /tmp/StudentsPerformance.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /tmp/StudentsPerformance.csv

# %%
# !hdfs dfs -ls /input
# Out:
# Found 1 items
# -rw-r--r--   1 root root       8907 2025-01-27 11:00 /input/archive_2.zip

# %%
# !hive
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/content/apache-hive-3.1.3-bin/lib/log4j-slf4j-impl-2.17.1.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hadoop-3.3.6/share/hadoop/common/lib/slf4j-reload4j-1.7.36.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Hive Session ID = c794e00c-fd73-407f-80f4-f57ca1e0d04d
#
# Logging initialized using configuration in jar:file:/content/apache-hive-3.1.3-bin/lib/hive-common-3.1.3.jar!/hive-log4j2.properties Async: true
# Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# Hive Session ID = 0f100b4e-3514-4fb5-946a-f1e29e777d20
# ...

# %%
# !hive
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/content/apache-hive-3.1.3-bin/lib/log4j-slf4j-impl-2.17.1.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hadoop-3.3.6/share/hadoop/common/lib/slf4j-reload4j-1.7.36.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Hive Session ID = 52adb49c-feea-445a-8cd5-2b8ae6c193c0
#
# Logging initialized using configuration in jar:file:/content/apache-hive-3.1.3-bin/lib/hive-common-3.1.3.jar!/hive-log4j2.properties Async: true
# Hive Session ID = 8b5183b1-397f-4f31-aa01-1df6e7762623
# Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# hive>

# %%
# !hive
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/content/apache-hive-3.1.3-bin/lib/log4j-slf4j-impl-2.17.1.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hadoop-3.3.6/share/hadoop/common/lib/slf4j-reload4j-1.7.36.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Hive Session ID = 85449e70-a9e0-41c0-b312-44941db6916f
#
# Logging initialized using configuration in jar:file:/content/apache-hive-3.1.3-bin/lib/hive-common-3.1.3.jar!/hive-log4j2.properties Async: true
# Hive Session ID = 63851a03-77be-41d7-b804-1fd8fb6082f2
# Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# ...
